# %% [markdown]
# # Model 3: using mixed data (satellite imagery and structured data) to predict where traffic accidents will happen

# %% [markdown]
# Additional data used to get the LSOA for each latitude and longitude point, in order to match with the population data.
#
# Source: https://data.london.gov.uk/dataset/mylondon

# %% [markdown]
# ### Importing the data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)
from scipy.spatial import cKDTree
from math import *
np.random.seed(123)

# %%
accidents = pd.read_csv('data/accidents/London_accidents_merged.csv')
accidents.head()
# Out:
#   Accident_Index  Longitude   Latitude Accident_Severity  Number_of_Vehicles  \
# 0  201301BS70003  -0.171402  51.486361           Serious                   2
# 1  201301BS70005  -0.173356  51.495115            Slight                   1
# 2  201301BS70006  -0.210767  51.518353            Slight                   1
# 3  201301BS70007  -0.209675  51.516808            Slight                   2
# 4  201301BS70009  -0.194332  51.492922            Slight                   2
#
#    Number_of_Casualties        Date Day_of_Week 1st_Road_Class  \
# 0                     1  2013-01-02   Wednesday              A
# 1                     2  2013-01-04      Friday              A
# 2                     1  2013-01-07      Monday              B
# 3                     1  2013-01-10    Thursday              B
# 4                     1  2013-01-04      Friday              A
#
#             Road_Type  Speed_limit          Junction_Detail 2nd_Road_Class  \
# 0  Single carriageway         30.0  T or staggered junction   Unclassified
# 1  Single carriageway         30.0               Crossroads              A
# 2  Single carriageway         30.0               Crossroads              B
# 3  Single carriageway         30.0               Crossroads              C
# 4      One way street         30.0  T or staggered junction   Unclassified
#
#         Light_Conditions  Weather_Conditions Road_Surface_Conditions  \
# 0               Daylight  Fine no high winds                     Dry
# 1               Daylight               Other                     Dry
# 2               Daylight  Fine no high winds                     Dry
# 3               Daylight  Fine no high winds                     Dry
# 4  Darkness - lights lit  Fine no high winds                     Dry
#
#   Urban_or_Rural_Area  Hour Two_Hour_Groupings   Time_of_Day Was_Daylight  \
# 0               Urban     9           8am-10am       Morning          Yes
# 1               Urban     8           8am-10am       Morning          Yes
# 2               Urban    11          10am-12pm  Office hours          Yes
# 3               Urban    10          10am-12pm  Office hours          Yes
# 4               Urban    17            4pm-6pm     Rush hour           No
#
#   Was_Bad_Weather Was_Road_Dry  log_Number_of_Casualties  \
# 0              No          Yes                  0.000000
# 1             Yes          Yes                  0.693147
# 2              No          Yes                  0.000000
# 3              No          Yes                  0.000000
# 4              No          Yes                  0.000000
#
#    log_Number_of_Vehicles       LSOA  population_per_hectare  bicycle_aadf  \
# 0                0.693147  E01002844                   110.8        1634.4
# 1                0.000000  E01002821                    74.6         559.6
# 2                0.000000  E01002878                   133.4           2.6
# 3                0.693147  E01002831                   179.2           2.6
# 4                0.693147  E01002851                   272.3         869.2
#
#    motorbike_aadf  car_aadf  bus_aadf  light_goods_vehicle_aadf  \
# 0           860.4   14888.0    1139.8                    2297.0
# 1          1516.0   28505.6    1396.2                    3868.6
# 2          3898.2   63274.8     763.4                   15253.6
# 3          3898.2   63274.8     763.4                   15253.6
# 4          1229.8   20478.6     897.2                    4951.6
#
#    heavy_goods_vehicle_aadf   Road RCat
# 0                     352.0  A3217   PA
# 1                    1003.0     A4   PA
# 2                    3185.8    A40   PA
# 3                    3185.8    A40   PA
# 4                    1251.4  A3220   PA

# %%
lsoa_latlong = pd.read_csv('data/geography/UK_LSOA_bounding_boxes.csv', usecols=['lsoa', 'Latitude', 'Longitude'])
lsoa_latlong.head()
# Out:
#         lsoa   Latitude  Longitude
# 0  E01000001  51.520269    -0.0950
# 1  E01000001  51.519848    -0.0967
# 2  E01000001  51.519030    -0.0962
# 3  E01000001  51.516904    -0.0981
# 4  E01000003  51.522376    -0.0973

# %%
population = pd.read_csv('data/population/Population_density.csv')
population = population.drop('Unnamed: 0', axis=1)
population.head()
# Out:
#         LSOA  population_per_hectare
# 0  E01012334                     0.4
# 1  E01012335                    12.1
# 2  E01012366                     0.3
# 3  E01033481                     9.3
# 4  E01033482                     6.9

# %%
traffic = pd.read_csv('data/traffic/Traffic_averages.csv')
traffic.head()
# Out:
#    S Ref Latitude  S Ref Longitude  bicycle_aadf  motorbike_aadf  car_aadf  \
# 0       49.915023        -6.317073         238.2            96.8     539.4
# 1       49.912343        -6.305686          87.4            79.4     629.0
# 2       49.917141        -6.306114         181.8           142.6     777.2
# 3       49.917810        -6.298996          61.2            54.8     342.8
# 4       49.918585        -6.295094          33.6            20.8     165.6
#
#    bus_aadf  light_goods_vehicle_aadf  heavy_goods_vehicle_aadf
# 0      27.0                     379.0                      40.4
# 1       9.0                     221.8                      11.0
# 2      32.2                     403.8                      29.4
# 3       6.0                     251.6                      34.4
# 4       0.0                     150.8                      15.2

# %%
# Combining the motor vehicle traffic columns
to_sum = ['motorbike_aadf', 'car_aadf', 'bus_aadf', 'light_goods_vehicle_aadf', 'heavy_goods_vehicle_aadf']
traffic['motor_vehicle_aadf'] = traffic[to_sum].sum(axis=1)
traffic.drop(to_sum, axis=1, inplace=True)
traffic.head()
# Out:
#    S Ref Latitude  S Ref Longitude  bicycle_aadf  motor_vehicle_aadf
# 0       49.915023        -6.317073         238.2              1082.6
# 1       49.912343        -6.305686          87.4               950.2
# 2       49.917141        -6.306114         181.8              1385.2
# 3       49.917810        -6.298996          61.2               689.6
# 4       49.918585        -6.295094          33.6               352.4

# %% [markdown]
# ### List of danger squares (from Sabatino)

# %%
model3_dataset_danger = pd.read_csv('data/accidents/model3_dataset_danger.csv')
model3_dataset_danger = model3_dataset_danger.drop('Unnamed: 0', axis=1)
model3_dataset_danger.head()
# Out:
#     Latitude  Longitude  population_per_hectare  bicycle_aadf  lat_4dp  \
# 0  51.522443  -0.127143                    55.0         782.2  51.5225
# 1  51.558820  -0.098667                   158.2         294.8  51.5590
# 2  51.447056   0.200494                    40.5          79.4  51.4470
# 3  51.487995  -0.221483                    96.7        1536.2  51.4880
# 4  51.622984  -0.090497                    93.7          84.6  51.6230
#
#    long_4dp     grid_square  motor_vehicle_aadf
# 0   -0.1270  51.5225,-0.127              2076.0
# 1   -0.0985  51.559,-0.0985               225.8
# 2    0.2005   51.447,0.2005              9458.0
# 3   -0.2215  51.488,-0.2215             22292.4
# 4   -0.0905  51.623,-0.0905             19072.8

# %% [markdown]
# ### List of safe squares

# %%
# Getting a list of all possible locations
# Setting parameters
lat_min, lat_max = 51.257, 51.719
lon_min, lon_max = -0.542, 0.291
grid_size = 0.0005

# Getting a list of all grid squares
lats = np.linspace(lat_min, lat_max, 925)
lons = np.linspace(lon_min, lon_max, 1667)
coords = [(round(x,4),round(y,4)) for x in lats for y in lons]

# Converting to a dataframe and adding a column for the grid square name
coords = pd.DataFrame(coords, columns=['lat_4dp', 'long_4dp'])
coords['grid_square'] = coords['lat_4dp'].map(str) + "," + coords['long_4dp'].map(str)
coords.head()
# Out:
#    lat_4dp  long_4dp     grid_square
# 0   51.257   -0.5420   51.257,-0.542
# 1   51.257   -0.5415  51.257,-0.5415
# 2   51.257   -0.5410   51.257,-0.541
# 3   51.257   -0.5405  51.257,-0.5405
# 4   51.257   -0.5400    51.257,-0.54

# %%
# Creating a list of all squares
all_squares = coords.grid_square
len(all_squares)
# Out:
# 1541975

# %%
# Creating a list of danger squares
danger_squares = model3_dataset_danger.grid_square
len(danger_squares)
# Out:
# 5000

# %%
# Creating a list of safe squares (all_squares minus danger_squares)
safe_squares = list(set(all_squares) - set(danger_squares))
print(len(safe_squares))
safe_squares = pd.DataFrame(safe_squares)
safe_squares.columns = ['grid_square']
safe_squares.head()
# Out:
# 1536975
#        grid_square
# 0  51.2765,-0.4385
# 1    51.4545,-0.39
# 2    51.289,-0.287
# 3   51.4675,-0.485
# 4   51.3855,0.2395

# %%
safe_squares_coords = safe_squares['grid_square'].str.split(',', expand=True)
safe_squares = pd.merge(safe_squares, safe_squares_coords, left_index=True, right_index=True)
safe_squares.columns = ['grid_square', 'latitude', 'longitude']
safe_squares.head()
# Out:
#        grid_square latitude longitude
# 0  51.2765,-0.4385  51.2765   -0.4385
# 1    51.4545,-0.39  51.4545     -0.39
# 2    51.289,-0.287   51.289    -0.287
# 3   51.4675,-0.485  51.4675    -0.485
# 4   51.3855,0.2395  51.3855    0.2395

# %%
def myround(x, base=.0005):
    return base * round(x/base)

# %%
#lsoa_latlong['lat_4dp'] = myround(lsoa_latlong['Latitude'])
#lsoa_latlong['long_4dp'] = myround(lsoa_latlong['Longitude'])
lsoa_latlong.head()
# Out:
#         lsoa   Latitude  Longitude  lat_4dp  long_4dp
# 0  E01000001  51.520269    -0.0950  51.5205   -0.0950
# 1  E01000001  51.519848    -0.0967  51.5200   -0.0965
# 2  E01000001  51.519030    -0.0962  51.5190   -0.0960
# 3  E01000001  51.516904    -0.0981  51.5170   -0.0980
# 4  E01000003  51.522376    -0.0973  51.5225   -0.0975

# %% [markdown]
# ### Adding traffic and population data to the safe squares

# %%
# Using cKDTree to add the LSOA names to the safe squares
# Extract lat and long subsets
square_coords = safe_squares[['latitude', 'longitude']]
lsoa_coords = lsoa_latlong[['Latitude', 'Longitude']]

# Construct tree
tree = cKDTree(lsoa_coords)

# Query the tree
distances, indices = tree.query(square_coords)

# Get the dataframe in the correct order
safe_squares_ordered = safe_squares.loc[indices]
safe_squares_ordered.reset_index(drop=True, inplace=True)

# Joining the dataframes
safe_squares = safe_squares_ordered.join(lsoa_latlong)

safe_squares.head()
# Out:
#        grid_square latitude longitude       lsoa   Latitude  Longitude  \
# 0   51.3945,-0.351  51.3945    -0.351  E01000001  51.520269    -0.0950
# 1   51.5045,0.2325  51.5045    0.2325  E01000001  51.519848    -0.0967
# 2   51.3945,-0.351  51.3945    -0.351  E01000001  51.519030    -0.0962
# 3    51.718,-0.361   51.718    -0.361  E01000001  51.516904    -0.0981
# 4  51.6305,-0.4075  51.6305   -0.4075  E01000003  51.522376    -0.0973
#
#    lat_4dp  long_4dp
# 0  51.5205   -0.0950
# 1  51.5200   -0.0965
# 2  51.5190   -0.0960
# 3  51.5170   -0.0980
# 4  51.5225   -0.0975

# %%
safe_squares_ordered
# Out:
#              grid_square latitude longitude
# 0         51.3945,-0.351  51.3945    -0.351
# 1         51.5045,0.2325  51.5045    0.2325
# 2         51.3945,-0.351  51.3945    -0.351
# 3          51.718,-0.361   51.718    -0.361
# 4        51.6305,-0.4075  51.6305   -0.4075
# 5         51.3955,-0.459  51.3955    -0.459
# 6         51.5045,-0.516  51.5045    -0.516
# 7          51.576,-0.342   51.576    -0.342
# 8         51.717,-0.1935   51.717   -0.1935
# 9          51.649,0.2555   51.649    0.2555
# 10        51.2645,-0.221  51.2645    -0.221
# 11        51.3945,-0.351  51.3945    -0.351
# 12          51.713,0.218   51.713     0.218
# 13         51.512,-0.225   51.512    -0.225
# 14        51.3485,-0.437  51.3485    -0.437
# 15         51.576,-0.342   51.576    -0.342
# 16        51.323,-0.1645   51.323   -0.1645
# 17         51.2975,-0.51  51.2975     -0.51
# 18         51.696,0.1485   51.696    0.1485
# 19       51.5555,-0.4825  51.5555   -0.4825
# 20         51.576,-0.342   51.576    -0.342
# 21          51.509,0.018   51.509     0.018
# 22          51.713,0.027   51.713     0.027
# 23         51.361,-0.389   51.361    -0.389
# 24       51.2775,-0.2825  51.2775   -0.2825
# 25       51.6485,-0.1455  51.6485   -0.1455
# 26        51.3195,-0.417  51.3195    -0.417
# 27          51.558,0.096   51.558     0.096
# 28         51.528,0.0955   51.528    0.0955
# 29        51.4285,-0.161  51.4285    -0.161
# ...                  ...      ...       ...
# 1536945    51.718,-0.361   51.718    -0.361
# 1536946  51.5195,-0.1925  51.5195   -0.1925
# 1536947     51.543,0.067   51.543     0.067
# 1536948   51.6395,-0.079  51.6395    -0.079
# 1536949  51.4185,-0.0125  51.4185   -0.0125
# 1536950    51.411,-0.013   51.411    -0.013
# 1536951   51.7175,0.1605  51.7175    0.1605
# 1536952   51.3945,-0.351  51.3945    -0.351
# 1536953   51.4255,0.2315  51.4255    0.2315
# 1536954   51.3955,-0.459  51.3955    -0.459
# 1536955    51.431,-0.541   51.431    -0.541
# 1536956      51.7,-0.269     51.7    -0.269
# 1536957  51.6305,-0.4075  51.6305   -0.4075
# 1536958   51.621,-0.4775   51.621   -0.4775
# 1536959   51.3955,-0.459  51.3955    -0.459
# 1536960   51.3955,-0.459  51.3955    -0.459
# 1536961  51.2575,-0.0575  51.2575   -0.0575
# 1536962   51.3945,-0.351  51.3945    -0.351
# 1536963     51.6355,0.17  51.6355      0.17
# 1536964  51.4815,-0.5025  51.4815   -0.5025
# 1536965   51.6135,-0.417  51.6135    -0.417
# 1536966    51.5605,0.108  51.5605     0.108
# 1536967     51.2915,-0.5  51.2915      -0.5
# 1536968   51.3955,-0.459  51.3955    -0.459
# 1536969   51.347,-0.1175   51.347   -0.1175
# 1536970     51.427,0.242   51.427     0.242
# 1536971    51.55,-0.2895    51.55   -0.2895
# 1536972   51.466,-0.3285   51.466   -0.3285
# 1536973   51.627,-0.1835   51.627   -0.1835
# 1536974    51.5085,0.068  51.5085     0.068
#
# [1536975 rows x 3 columns]

# %%
distances.mean()
# Out:
# 0.02819339665827583

# %%
safe_squares[['latitude', 'longitude']] = safe_squares[['latitude', 'longitude']].astype(float)

# %%
safe_squares.latitude.dtype
# Out:
# dtype('float64')

# %%
safe_squares = safe_squares.dropna()

# %%
len(safe_squares)
# Out:
# 25053

# %%
def distance_m(lat1, lon1, lat2, lon2):
    """Returns the distance in metres between two points described by latitudes and longitudes using the Haversine formula"""
    p = 0.017453292519943295
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p)*cos(lat2*p) * (1-cos((lon2-lon1)*p)) / 2
    return (12742 * asin(sqrt(a)))*1000
	
# Calculating the distances between the accident and traffic count locations in each row
distances_m = []                    
for index, row in safe_squares.iterrows():
    lat1 = row['latitude'] 
    lon1 = row['longitude'] 
    lat2 = row['Latitude'] 
    lon2 = row['Longitude'] 
    value = distance_m(lat1, lon1, lat2, lon2) 
    distances_m.append(value)
	
print("Mean:", round(np.mean(distances_m),1))
print("Median:", round(np.median(distances_m),1))
print("Minimum:", round(min(distances_m),1))
print("Maximum:", round(max(distances_m),1))
# Out:
# Mean: 24342.2
# Median: 24125.1
# Minimum: 292.6
# Maximum: 60742.2

# %%
safe_squares_ordered.head()
# Out:
#        grid_square latitude longitude
# 0   51.3945,-0.351  51.3945    -0.351
# 1   51.5045,0.2325  51.5045    0.2325
# 2   51.3945,-0.351  51.3945    -0.351
# 3    51.718,-0.361   51.718    -0.361
# 4  51.6305,-0.4075  51.6305   -0.4075

# %%
safe_squares_ordered.join(lsoa_latlong)
# Out:
#              grid_square latitude longitude       lsoa   Latitude  Longitude  \
# 0         51.3945,-0.351  51.3945    -0.351  E01000001  51.520269  -0.095000
# 1         51.5045,0.2325  51.5045    0.2325  E01000001  51.519848  -0.096700
# 2         51.3945,-0.351  51.3945    -0.351  E01000001  51.519030  -0.096200
# 3          51.718,-0.361   51.718    -0.361  E01000001  51.516904  -0.098100
# 4        51.6305,-0.4075  51.6305   -0.4075  E01000003  51.522376  -0.097300
# 5         51.3955,-0.459  51.3955    -0.459  E01000003  51.522085  -0.096000
# 6         51.5045,-0.516  51.5045    -0.516  E01000003  51.520924  -0.096500
# 7          51.576,-0.342   51.576    -0.342  E01000003  51.522014  -0.097200
# 8         51.717,-0.1935   51.717   -0.1935  E01000002  51.520970  -0.093800
# 9          51.649,0.2555   51.649    0.2555  E01000002  51.520504  -0.092800
# 10        51.2645,-0.221  51.2645    -0.221  E01000002  51.519073  -0.093300
# 11        51.3945,-0.351  51.3945    -0.351  E01000002  51.519679  -0.091800
# 12          51.713,0.218   51.713     0.218  E01000002  51.519125  -0.090978
# 13         51.512,-0.225   51.512    -0.225  E01000002  51.518794  -0.092700
# 14        51.3485,-0.437  51.3485    -0.437  E01000003  51.522894  -0.096000
# 15         51.576,-0.342   51.576    -0.342  E01000003  51.522431  -0.095200
# 16        51.323,-0.1645   51.323   -0.1645  E01032739  51.513450  -0.101448
# 17         51.2975,-0.51  51.2975     -0.51  E01032740  51.513299  -0.108804
# 18         51.696,0.1485   51.696    0.1485  E01032740  51.517404  -0.101283
# 19       51.5555,-0.4825  51.5555   -0.4825  E01032740  51.518743  -0.100651
# 20         51.576,-0.342   51.576    -0.342  E01032740  51.514670  -0.110189
# 21          51.509,0.018   51.509     0.018  E01000005  51.512283  -0.074000
# 22          51.713,0.027   51.713     0.027  E01000005  51.515925  -0.076700
# 23         51.361,-0.389   51.361    -0.389  E01000005  51.515842  -0.077100
# 24       51.2775,-0.2825  51.2775   -0.2825  E01000005  51.512999  -0.073800
# 25       51.6485,-0.1455  51.6485   -0.1455  E01032739  51.510670  -0.079800
# 26        51.3195,-0.417  51.3195    -0.417  E01000009  51.541976   0.082891
# 27          51.558,0.096   51.558     0.096  E01000011  51.542695   0.082923
# 28         51.528,0.0955   51.528    0.0955  E01000012  51.542657   0.069800
# 29        51.4285,-0.161  51.4285    -0.161  E01000007  51.539136   0.075695
# ...                  ...      ...       ...        ...        ...        ...
# 1536945    51.718,-0.361   51.718    -0.361        NaN        NaN        NaN
# 1536946  51.5195,-0.1925  51.5195   -0.1925        NaN        NaN        NaN
# 1536947     51.543,0.067   51.543     0.067        NaN        NaN        NaN
# 1536948   51.6395,-0.079  51.6395    -0.079        NaN        NaN        NaN
# 1536949  51.4185,-0.0125  51.4185   -0.0125        NaN        NaN        NaN
# 1536950    51.411,-0.013   51.411    -0.013        NaN        NaN        NaN
# 1536951   51.7175,0.1605  51.7175    0.1605        NaN        NaN        NaN
# 1536952   51.3945,-0.351  51.3945    -0.351        NaN        NaN        NaN
# 1536953   51.4255,0.2315  51.4255    0.2315        NaN        NaN        NaN
# 1536954   51.3955,-0.459  51.3955    -0.459        NaN        NaN        NaN
# 1536955    51.431,-0.541   51.431    -0.541        NaN        NaN        NaN
# 1536956      51.7,-0.269     51.7    -0.269        NaN        NaN        NaN
# 1536957  51.6305,-0.4075  51.6305   -0.4075        NaN        NaN        NaN
# 1536958   51.621,-0.4775   51.621   -0.4775        NaN        NaN        NaN
# 1536959   51.3955,-0.459  51.3955    -0.459        NaN        NaN        NaN
# 1536960   51.3955,-0.459  51.3955    -0.459        NaN        NaN        NaN
# 1536961  51.2575,-0.0575  51.2575   -0.0575        NaN        NaN        NaN
# 1536962   51.3945,-0.351  51.3945    -0.351        NaN        NaN        NaN
# 1536963     51.6355,0.17  51.6355      0.17        NaN        NaN        NaN
# 1536964  51.4815,-0.5025  51.4815   -0.5025        NaN        NaN        NaN
# 1536965   51.6135,-0.417  51.6135    -0.417        NaN        NaN        NaN
# 1536966    51.5605,0.108  51.5605     0.108        NaN        NaN        NaN
# 1536967     51.2915,-0.5  51.2915      -0.5        NaN        NaN        NaN
# 1536968   51.3955,-0.459  51.3955    -0.459        NaN        NaN        NaN
# 1536969   51.347,-0.1175   51.347   -0.1175        NaN        NaN        NaN
# 1536970     51.427,0.242   51.427     0.242        NaN        NaN        NaN
# 1536971    51.55,-0.2895    51.55   -0.2895        NaN        NaN        NaN
# 1536972   51.466,-0.3285   51.466   -0.3285        NaN        NaN        NaN
# 1536973   51.627,-0.1835   51.627   -0.1835        NaN        NaN        NaN
# 1536974    51.5085,0.068  51.5085     0.068        NaN        NaN        NaN
#
#          lat_4dp  long_4dp
# 0        51.5205   -0.0950
# 1        51.5200   -0.0965
# 2        51.5190   -0.0960
# 3        51.5170   -0.0980
# 4        51.5225   -0.0975
# 5        51.5220   -0.0960
# 6        51.5210   -0.0965
# 7        51.5220   -0.0970
# 8        51.5210   -0.0940
# 9        51.5205   -0.0930
# 10       51.5190   -0.0935
# 11       51.5195   -0.0920
# 12       51.5190   -0.0910
# 13       51.5190   -0.0925
# 14       51.5230   -0.0960
# 15       51.5225   -0.0950
# 16       51.5135   -0.1015
# 17       51.5135   -0.1090
# 18       51.5175   -0.1015
# 19       51.5185   -0.1005
# 20       51.5145   -0.1100
# 21       51.5125   -0.0740
# 22       51.5160   -0.0765
# 23       51.5160   -0.0770
# 24       51.5130   -0.0740
# 25       51.5105   -0.0800
# 26       51.5420    0.0830
# 27       51.5425    0.0830
# 28       51.5425    0.0700
# 29       51.5390    0.0755
# ...          ...       ...
# 1536945      NaN       NaN
# 1536946      NaN       NaN
# 1536947      NaN       NaN
# 1536948      NaN       NaN
# 1536949      NaN       NaN
# 1536950      NaN       NaN
# 1536951      NaN       NaN
# 1536952      NaN       NaN
# 1536953      NaN       NaN
# 1536954      NaN       NaN
# 1536955      NaN       NaN
# 1536956      NaN       NaN
# 1536957      NaN       NaN
# 1536958      NaN       NaN
# 1536959      NaN       NaN
# 1536960      NaN       NaN
# 1536961      NaN       NaN
# 1536962      NaN       NaN
# 1536963      NaN       NaN
# 1536964      NaN       NaN
# 1536965      NaN       NaN
# 1536966      NaN       NaN
# 1536967      NaN       NaN
# 1536968      NaN       NaN
# 1536969      NaN       NaN
# 1536970      NaN       NaN
# 1536971      NaN       NaN
# 1536972      NaN       NaN
# 1536973      NaN       NaN
# 1536974      NaN       NaN
#
# [1536975 rows x 8 columns]

# %%
len(safe_squares_ordered)
# Out:
# 1536975

# %%
len(safe_squares)
# Out:
# 7812821

# %%
safe_squares.drop(['Latitude', 'Longitude'], axis=1, inplace=True)

# %%
safe_squares.lsoa.nunique()
# Out:
# 4835

# %%
safe_squares.lsoa.value_counts(normalize=True, dropna=False)
# Out:
# NaN          0.983700
# E01033583    0.000008
# E01004749    0.000007
# E01001646    0.000007
# E01004252    0.000007
# E01001756    0.000006
# E01003475    0.000006
# E01004012    0.000006
# E01001859    0.000006
# E01003482    0.000006
# E01004745    0.000006
# E01000718    0.000006
# E01000092    0.000006
# E01001754    0.000006
# E01004656    0.000006
# E01004142    0.000006
# E01033725    0.000006
# E01004215    0.000006
# E01003617    0.000006
# E01001519    0.000006
# E01033724    0.000006
# E01004509    0.000006
# E01003367    0.000006
# E01001748    0.000006
# E01004222    0.000005
# E01001731    0.000005
# E01004393    0.000005
# E01001948    0.000005
# E01001437    0.000005
# E01002684    0.000005
#                ...
# E01033734    0.000002
# E01033492    0.000002
# E01033731    0.000002
# E01002666    0.000002
# E01033341    0.000002
# E01002197    0.000002
# E01032774    0.000002
# E01000599    0.000002
# E01033713    0.000002
# E01033486    0.000002
# E01001847    0.000002
# E01001795    0.000002
# E01002175    0.000002
# E01003016    0.000002
# E01002199    0.000002
# E01033574    0.000002
# E01001464    0.000002
# E01002170    0.000002
# E01033083    0.000002
# E01033711    0.000002
# E01001373    0.000002
# E01032772    0.000002
# E01033487    0.000002
# E01004248    0.000002
# E01001867    0.000002
# E01033603    0.000002
# E01002953    0.000002
# E01033493    0.000002
# E01033135    0.000002
# E01032773    0.000001
# Name: lsoa, Length: 4836, dtype: float64

# %%
safe_squares_merged = pd.merge(safe_squares, population, how='left', left_on='lsoa', right_on='LSOA')

# %%
len(population)
# Out:
# 34753

# %%
# Using cKDTree to add the traffic to the safe squares
# Extract lat and long subsets
traffic_coords = traffic[['S Ref Latitude', 'S Ref Longitude']]
square_coords = safe_squares_merged[['latitude', 'longitude']]

# Construct tree
tree = cKDTree(traffic_coords)

# Query the tree
distances, indices = tree.query(square_coords)

# Get the dataframe in the correct order
traffic_ordered = traffic.loc[indices]
traffic_ordered.reset_index(drop=True, inplace=True)

# Joining the dataframes
safe_squares_merged = safe_squares_merged.join(traffic_ordered)

safe_squares_merged.head()
# Out:
#      grid_square latitude longitude       lsoa       LSOA  \
# 0  51.522,0.2015   51.522    0.2015  E01000001  E01000001
# 1  51.382,0.1175   51.382    0.1175  E01000001  E01000001
# 2  51.6855,-0.53  51.6855     -0.53  E01000001  E01000001
# 3   51.652,0.009   51.652     0.009  E01000001  E01000001
# 4   51.366,0.197   51.366     0.197  E01000003  E01000003
#
#    population_per_hectare  S Ref Latitude  S Ref Longitude  bicycle_aadf  \
# 0                   112.9       51.521151         0.203892          31.6
# 1                   112.9       51.381924         0.106944         123.8
# 2                   112.9       51.670716        -0.540878          43.4
# 3                   112.9       51.666079        -0.000067          54.0
# 4                   227.7       51.383861         0.211661          18.6
#
#    motor_vehicle_aadf
# 0             20922.2
# 1             15964.6
# 2             13352.0
# 3             16842.6
# 4             20441.6

# %%
safe_squares_merged.drop(['lsoa', 'LSOA', 'S Ref Latitude', 'S Ref Longitude'], axis=1, inplace=True)

# %%
safe_squares_merged.head()
# Out:
#      grid_square latitude longitude  population_per_hectare  bicycle_aadf  \
# 0  51.522,0.2015   51.522    0.2015                   112.9          31.6
# 1  51.382,0.1175   51.382    0.1175                   112.9         123.8
# 2  51.6855,-0.53  51.6855     -0.53                   112.9          43.4
# 3   51.652,0.009   51.652     0.009                   112.9          54.0
# 4   51.366,0.197   51.366     0.197                   227.7          18.6
#
#    motor_vehicle_aadf
# 0             20922.2
# 1             15964.6
# 2             13352.0
# 3             16842.6
# 4             20441.6

# %%
len(safe_squares_merged[safe_squares_merged['population_per_hectare'].isna()])
# Out:
# 1511922

# %%
1536975 - 1511922
# Out:
# 25053

# %% [markdown]
# ### List of safe squares to sample

# %%
safe_squares_5000 = safe_squares_merged.sample(n=5000, replace=False, random_state=0)

# %%
safe_squares_5000.head()
# Out:
#              grid_square latitude longitude  population_per_hectare  \
# 1045317  51.3935,-0.2295  51.3935   -0.2295                     NaN
# 1229295    51.412,-0.063   51.412    -0.063                     NaN
# 606106     51.605,-0.524   51.605    -0.524                     NaN
# 4681      51.4755,-0.398  51.4755    -0.398                    99.8
# 970575    51.3205,-0.217  51.3205    -0.217                     NaN
#
#          bicycle_aadf  motor_vehicle_aadf
# 1045317          64.4              5878.4
# 1229295         110.0             11850.2
# 606106            0.0            148872.0
# 4681            408.2             53150.2
# 970575           79.8             34077.8

# %%
safe_squares_5000.population_per_hectare.value_counts(normalize=True, dropna=False)
# Out:
# NaN       0.9842
#  63.2     0.0002
#  37.4     0.0002
#  52.2     0.0002
#  184.1    0.0002
#  190.9    0.0002
#  128.1    0.0002
#  121.6    0.0002
#  56.2     0.0002
#  82.2     0.0002
#  27.2     0.0002
#  75.0     0.0002
#  227.7    0.0002
#  134.3    0.0002
#  118.1    0.0002
#  43.4     0.0002
#  22.1     0.0002
#  110.2    0.0002
#  226.1    0.0002
#  98.0     0.0002
#  202.5    0.0002
#  48.2     0.0002
#  102.2    0.0002
#  240.0    0.0002
#  37.0     0.0002
#  134.2    0.0002
#  37.8     0.0002
#  91.8     0.0002
#  233.0    0.0002
#  174.6    0.0002
#            ...
#  27.4     0.0002
#  145.6    0.0002
#  125.4    0.0002
#  118.2    0.0002
#  55.5     0.0002
#  284.8    0.0002
#  141.3    0.0002
#  149.8    0.0002
#  45.4     0.0002
#  39.6     0.0002
#  68.1     0.0002
#  235.0    0.0002
#  150.8    0.0002
#  164.0    0.0002
#  71.2     0.0002
#  79.9     0.0002
#  43.9     0.0002
#  99.8     0.0002
#  103.7    0.0002
#  22.9     0.0002
#  7.4      0.0002
#  88.1     0.0002
#  232.4    0.0002
#  53.4     0.0002
#  15.9     0.0002
#  58.5     0.0002
#  55.1     0.0002
#  140.2    0.0002
#  108.9    0.0002
#  53.6     0.0002
# Name: population_per_hectare, Length: 80, dtype: float64

# %%
safe_squares_download = list(safe_squares_5000.grid_square)

# %%
# Saving list to csv in case the kernel is restarted and the list is lost
# Will scrape images from this list in Scraping_Real_Images notebook
pd.Series(safe_squares_download).to_csv('data/accidents/safe_squares_download', index=False)

# %% [markdown]
# ### Merging Safe and Danger datasets
